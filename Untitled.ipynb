# %%
pip3 install sodapy
# Out:
#   File "/var/folders/rz/fm6f1m9d3d1_92kkr2jd0zfh0000gn/T/ipykernel_16410/3845105689.py", line 1
#     pip3 install sodapy
#          ^
# SyntaxError: invalid syntax

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
#pip3 install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.sfgov.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.sfgov.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("nuek-vuh3", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.head()
# Out:
#   call_number unit_id incident_number         call_type  \
# 0   220381092     E31        22017753            Alarms
# 1   210690030     T03        21030278            Alarms
# 2   203421272  BLS841        20139667  Medical Incident
# 3   213602525     T10        21160001    Structure Fire
# 4   210683285      58        21030264    Structure Fire
#
#                  call_date               watch_date            received_dttm  \
# 0  2022-02-07T00:00:00.000  2022-02-07T00:00:00.000  2022-02-07T10:59:48.000
# 1  2021-03-10T00:00:00.000  2021-03-09T00:00:00.000  2021-03-10T00:16:03.000
# 2  2020-12-07T00:00:00.000  2020-12-07T00:00:00.000  2020-12-07T11:26:17.000
# 3  2021-12-26T00:00:00.000  2021-12-26T00:00:00.000  2021-12-26T23:30:51.000
# 4  2021-03-09T00:00:00.000  2021-03-09T00:00:00.000  2021-03-09T23:06:09.000
#
#                 entry_dttm            dispatch_dttm            response_dttm  \
# 0  2022-02-07T11:01:36.000  2022-02-07T11:01:42.000  2022-02-07T11:03:37.000
# 1  2021-03-10T00:18:36.000  2021-03-10T00:19:01.000  2021-03-10T00:20:15.000
# 2  2020-12-07T11:26:17.000  2020-12-07T11:26:17.000  2020-12-07T11:26:17.000
# 3  2021-12-26T23:32:21.000  2021-12-26T23:34:41.000  2021-12-26T23:38:10.000
# 4  2021-03-09T23:08:23.000  2021-03-09T23:08:35.000  2021-03-09T23:08:43.000
#
#    ... unit_type unit_sequence_in_call_dispatch fire_prevention_district  \
# 0  ...    ENGINE                              1                        7
# 1  ...     TRUCK                              3                        2
# 2  ...     CHIEF                              1                        4
# 3  ...     TRUCK                              4                        5
# 4  ...     MEDIC                             10                        2
#
#   supervisor_district neighborhoods_analysis_boundaries             rowid  \
# 0                   1                    Inner Richmond     220381092-E31
# 1                   6                        Tenderloin     210690030-T03
# 2                   2                            Marina  203421272-BLS841
# 3                   5                 Lone Mountain/USF     213602525-T10
# 4                   6                        Tenderloin      210683285-58
#
#                                        case_location  \
# 0  {'type': 'Point', 'coordinates': [-122.4703039...
# 1  {'type': 'Point', 'coordinates': [-122.4169793...
# 2                                                NaN
# 3  {'type': 'Point', 'coordinates': [-122.4509485...
# 4  {'type': 'Point', 'coordinates': [-122.4132437...
#
#   :@computed_region_ajp5_b2md transport_dttm hospital_dttm
# 0                          11            NaN           NaN
# 1                          36            NaN           NaN
# 2                         NaN            NaN           NaN
# 3                          18            NaN           NaN
# 4                          36            NaN           NaN
#
# [5 rows x 35 columns]

# %%
https://data.texas.gov/resource/ct7p-bmtg.json

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
#pip3 install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.texas.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.sfgov.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("ct7p-bmtg")

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df.count
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# ..                       ...            ...                     ...
# 995  1992-05-23T00:00:00.000           45.0    Denied on 07/20/2021
# 996  2011-05-26T00:00:00.000            5.0    Denied on 08/16/2021
# 997  2006-12-18T00:00:00.000           25.0  Approved on 08/11/2021
# 998  1989-05-20T00:00:00.000           70.0    Denied on 09/01/2016
# 999  1991-03-01T00:00:00.000           75.0  Approved on 07/06/2021
#
#        next_parole_review_date      parole_review_status
# 0                   08/03/2026     NOT IN REVIEW PROCESS
# 1                          N/A     NOT IN REVIEW PROCESS
# 2                      07/2024     NOT IN REVIEW PROCESS
# 3                   12/02/2022     NOT IN REVIEW PROCESS
# 4                      09/2022     NOT IN REVIEW PROCESS
# ..                         ...                       ...
# 995                    07/2022     NOT IN REVIEW PROCESS
# 996                    08/2022     NOT IN REVIEW PROCESS
# 997                        N/A     NOT IN REVIEW PROCESS
# 998  Unavailable at this time.  IN PAROLE REVIEW PROCESS
# 999                        N/A     NOT IN REVIEW PROCESS
#
# [1000 rows x 20 columns]>

# %%
results_df.head()
# Out:
#   sid_number tdcj_number                  name current_facility gender  \
# 0   00524524    00758486  HARPER,DAVID JOHN JR          Estelle      M
# 1   00703267    00841623    RODRIGUEZ,THEODORE             Beto      M
# 2   00770626    00449674         FLORES,ISABEL             Pack      M
# 3   00771601    01491019     MOLETT,JOHN HENRY             Pack      M
# 4   00779423    01241039       CARAWAY,LEON JR     C.T. Terrell      M
#
#        race age        projected_release    maximum_sentence_date  \
# 0     White  92  9999-01-01T00:00:00.000  9999-01-01T00:00:00.000
# 1     White  83  2021-10-01T00:00:00.000  2043-08-03T00:00:00.000
# 2  Hispanic  84  9999-01-01T00:00:00.000  9999-01-01T00:00:00.000
# 3     Black  79  2037-12-02T00:00:00.000  2037-12-02T00:00:00.000
# 4     Black  84  2023-06-19T00:00:00.000  2023-06-19T00:00:00.000
#
#    parole_eligibility_date  case_number    county offense_code  \
# 0  2026-08-03T00:00:00.000     95-765-C  McLennan     11180000
# 1  2021-02-01T00:00:00.000     97-396-C  McLennan     11990003
# 2  2006-09-02T00:00:00.000  86CR-1234-B    Nueces     09150000
# 3  2022-12-02T00:00:00.000      1144294    Harris     12990002
# 4  2013-06-18T00:00:00.000  04CR-16,149    Shelby     11990003
#
#           tdcj_offense            sentence_date             offense_date  \
# 0   AGG SEXUAL ASSAULT  1996-08-13T00:00:00.000  1995-09-15T00:00:00.000
# 1         AGG SEX ASLT  1998-08-05T00:00:00.000  1996-06-01T00:00:00.000
# 2  MURDER W/DEADLY WPN  1987-04-13T00:00:00.000  1986-09-02T00:00:00.000
# 3     AGG ROBBERY W/DW  2008-02-21T00:00:00.000  2007-12-03T00:00:00.000
# 4      AGG SEXUAL ALST  2004-05-13T00:00:00.000  1999-07-24T00:00:00.000
#
#   sentence_years    last_parole_decision next_parole_review_date  \
# 0           Life                    None              08/03/2026
# 1           45.0  Approved on 08/18/2021                     N/A
# 2           Life    Denied on 07/21/2021                 07/2024
# 3           30.0                    None              12/02/2022
# 4           20.0    Denied on 10/30/2019                 09/2022
#
#     parole_review_status
# 0  NOT IN REVIEW PROCESS
# 1  NOT IN REVIEW PROCESS
# 2  NOT IN REVIEW PROCESS
# 3  NOT IN REVIEW PROCESS
# 4  NOT IN REVIEW PROCESS
